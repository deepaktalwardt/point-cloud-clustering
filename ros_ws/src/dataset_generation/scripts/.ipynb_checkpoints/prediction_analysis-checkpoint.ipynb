# %% [markdown]
# This python notebook is for calculating confusion matrix,heatmap,recall and precision for very object in a one json file.
# We are giving json file which has atleast 10 points in each object.
# If you want to run for 50,100,300,500 points json you can download that files from https://drive.google.com/drive/u/0/folders/1UihUt7aVNLGXXRiTDjNyMBr2hCP-3RLc

# %%
import json
import pandas as pd
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import precision_score, recall_score
from sklearn.preprocessing import normalize

# %%
# Loading json file and displying from given path
path_to_folder = 'point-cloud-clustering/ros_ws/src/dataset_generation/scripts/test_json/'
result_file_name = 'test_results_sources_1_10_icp.json'
f = open(path_to_folder + result_file_name)
data = json.load(f)
print(data)
# Out:
# {'Hatchback-1589078373948922-3.pcd': {'num_points': 12, 'tests': {'Hatchback': {'fitness_score': 0.7281691250630327, 'has_converged': False}, 'Jeep': {'fitness_score': 0.7219681531983947, 'has_converged': False}, 'SUV': {'fitness_score': 0.7517561094380899, 'has_converged': False}, 'Sedan': {'fitness_score': 0.7694464414159945, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078373988922-3.pcd': {'num_points': 12, 'tests': {'Hatchback': {'fitness_score': 0.82369450608084, 'has_converged': False}, 'Jeep': {'fitness_score': 0.8891315811236638, 'has_converged': False}, 'SUV': {'fitness_score': 0.8538827754375349, 'has_converged': False}, 'Sedan': {'fitness_score': 0.8792254571421998, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078374448921-3.pcd': {'num_points': 12, 'tests': {'Hatchback': {'fitness_score': 0.8685448358393374, 'has_converged': False}, 'Jeep': {'fitness_score': 0.8834228580387115, 'has_converged': False}, 'SUV': {'fitness_score': 1.0942681868321416, 'has_converged': False}, 'Sedan': {'fitness_score': 0.9738481332913044, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078374448921-5.pcd': {'num_points': 15, 'tests': {'Hatchback': {'fitness_score': 0.6497993890337103, 'has_converged': False}, 'Jeep': {'fitness_score': 0.663673897212731, 'has_converged': False}, 'SUV': {'fitness_score': 0.6793991700566712, 'has_converged': False}, 'Sedan': {'fitness_score': 0.6784174714967589, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078374518921-4.pcd': {'num_points': 12, 'tests': {'Hatchback': {'fitness_score': 0.5803946832917163, 'has_converged': False}, 'Jeep': {'fitness_score': 0.5620958897233825, 'has_converged': False}, 'SUV': {'fitness_score': 0.7732046508842664, 'has_converged': False}, 'Sedan': {'fitness_score': 0.6545814713117364, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078374518921-6.pcd': {'num_points': 16, 'tests': {'Hatchback': {'fitness_score': 0.4086199824188507, 'has_converged': False}, 'Jeep': {'fitness_score': 0.39496667615748543, 'has_converged': False}, 'SUV': {'fitness_score': 0.4546288738445139, 'has_converged': False}, 'Sedan': {'fitness_score': 0.44686252078724753, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078374558921-4.pcd': {'num_points': 12, 'tests': {'Hatchback': {'fitness_score': 0.502163105271604, 'has_converged': False}, 'Jeep': {'fitness_score': 0.5188935169163558, 'has_converged': False}, 'SUV': {'fitness_score': 0.6352335758094293, 'has_converged': False}, 'Sedan': {'fitness_score': 0.5618061110804202, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078374558921-6.pcd': {'num_points': 17, 'tests': {'Hatchback': {'fitness_score': 0.4550117509683387, 'has_converged': False}, 'Jeep': {'fitness_score': 0.4650934808365227, 'has_converged': False}, 'SUV': {'fitness_score': 0.5051387981169508, 'has_converged': False}, 'Sedan': {'fitness_score': 0.49505561451173147, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078374588921-4.pcd': {'num_points': 10, 'tests': {'Hatchback': {'fitness_score': 0.795848174625708, 'has_converged': False}, 'Jeep': {'fitness_score': 0.8854893993443931, 'has_converged': False}, 'SUV': {'fitness_score': 1.1199348202567518, 'has_converged': False}, 'Sedan': {'fitness_score': 0.901274135858029, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078374588921-6.pcd': {'num_points': 17, 'tests': {'Hatchback': {'fitness_score': 0.6818735340351145, 'has_converged': False}, 'Jeep': {'fitness_score': 0.7614363222641859, 'has_converged': False}, 'SUV': {'fitness_score': 0.7621031960255249, 'has_converged': False}, 'Sedan': {'fitness_score': 0.7240404496681511, 'has_converged': False}}, 'true_label': 'Hatchback'}, 'Hatchback-1589078374628921-4.pcd': {'num_points': 9, 'tests': {'Hatchback': {'fitness_score': 1.1063093049891022, 'has_converged': False}, 'Jeep': {'fitness_score': 1.1114 ...

# %%
# giving labels
# labels = ['Hatchback', 'Jeep', 'SUV', 'Sedan']

# %%
# Plot confusion Matrix
predicted = []
true_label = []

for line in data:
    collect = []
    converged = []
    for test_result in data[line]:
        if test_result == 'tests':
            for label in labels:
                if (data[line][test_result][label]['has_converged']):
                    converged.append((data[line][test_result][label]['fitness_score'], label))
                collect.append((data[line][test_result][label]['fitness_score'], label))

    if len(converged) == 1:  # If only converged to 1 label
        # pass
        predicted.append(converged[0][1])
        true_label.append(data[line]['true_label'])
    elif len(converged) > 1:  # If converged to more than one, choose the one with lowest score
              # pass
        converged.sort()
        predicted.append(converged[0][1])
        true_label.append(data[line]['true_label'])
    else:  # If didn't converge to any, choose the label with lowest error
              pass
        # if collect:
        #     collect.sort()
        #     predicted.append(collect[0][1])
        #     true_label.append(data[line]['true_label'])

cm = confusion_matrix(true_label, predicted, labels=labels, normalize='true')
print(cm)

# %% [markdown]
# Confusion matrix:
# [[0.515625 0.3125 0.0625 0.109375 ]
# [0.07751938 0.75968992 0.14728682 0.01550388]
# [0. 0.22857143 0.7047619 0.06666667]
# [0.32307692 0.13846154 0.16153846 0.37692308]]

# %%
#Printing data and true labels
print(len(data))
print(len(true_label))
# Out:
# 7376
# 428

# %%
#displaying heatmap for all objects 
df_cm = pd.DataFrame(cm, index = [i for i in labels],
                      columns = [i for i in labels])
sns.set(font_scale=1.3)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_cm, annot=True, cmap="Blues", ax=ax)

# %% [markdown]
# You can see heatmap of this files on https://drive.google.com/drive/u/0/folders/1HuXju-1GFQmQVL_IQxvpU-wnFcQiCGKI

# %%
# Calculate Precision and Recall
print("recall :", recall_score(true_label, predicted, labels, average=None))
print("precision :", precision_score(true_label, predicted, labels,average=None))

# %% [markdown]
# Recall : [0.515625 0.75968992 0.7047619 0.37692308]
# precision : [0.38823529 0.6125 0.62711864 0.75384615]
